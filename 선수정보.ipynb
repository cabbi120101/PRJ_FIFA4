# %%
import json
import pandas as pd
import requests

from pandas import DataFrame
from tqdm.notebook import tqdm

# %%
match_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json')
match_parsed_data = match_url.json()
match_type = pd.DataFrame(match_parsed_data)

# %%
match_type.head()
# Out:
#    matchtype      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선

# %%
# grade_data의 matchType 합치기 위한 전처리
match_type = match_type.rename(columns={'matchtype' : 'matchType'}) # 변수명 변경
match_type.head()
# Out:
#    matchType      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선

# %%
# 피파온라인 등급 정보 데이터
division_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/division.json')
division_parsed_data = division_url.json()
print('division JSON : ', division_parsed_data)
division_data = pd.DataFrame(division_parsed_data)
division_data
# Out:
# division JSON :  [{'divisionId': 800, 'divisionName': '슈퍼챔피언스'}, {'divisionId': 900, 'divisionName': '챔피언스'}, {'divisionId': 1000, 'divisionName': '슈퍼챌린지'}, {'divisionId': 1100, 'divisionName': '챌린지1'}, {'divisionId': 1200, 'divisionName': '챌린지2'}, {'divisionId': 1300, 'divisionName': '챌린지3'}, {'divisionId': 2000, 'divisionName': '월드클래스1'}, {'divisionId': 2100, 'divisionName': '월드클래스2'}, {'divisionId': 2200, 'divisionName': '월드클래스3'}, {'divisionId': 2300, 'divisionName': '프로1'}, {'divisionId': 2400, 'divisionName': '프로2'}, {'divisionId': 2500, 'divisionName': '프로3'}, {'divisionId': 2600, 'divisionName': '세미프로1'}, {'divisionId': 2700, 'divisionName': '세미프로2'}, {'divisionId': 2800, 'divisionName': '세미프로3'}, {'divisionId': 2900, 'divisionName': '유망주1'}, {'divisionId': 3000, 'divisionName': '유망주2'}, {'divisionId': 3100, 'divisionName': '유망주3'}]
#     divisionId divisionName
# 0          800       슈퍼챔피언스
# 1          900         챔피언스
# 2         1000        슈퍼챌린지
# 3         1100         챌린지1
# 4         1200         챌린지2
# 5         1300         챌린지3
# 6         2000       월드클래스1
# 7         2100       월드클래스2
# 8         2200       월드클래스3
# 9         2300          프로1
# 10        2400          프로2
# 11        2500          프로3
# 12        2600        세미프로1
# 13        2700        세미프로2
# 14        2800        세미프로3
# 15        2900         유망주1
# 16        3000         유망주2
# 17        3100         유망주3

# %%
# division_data 데이터 전처리
division_data = division_data.rename(columns = {'divisionId' : 'division'})
division_data
# Out:
#     division divisionName
# 0        800       슈퍼챔피언스
# 1        900         챔피언스
# 2       1000        슈퍼챌린지
# 3       1100         챌린지1
# 4       1200         챌린지2
# 5       1300         챌린지3
# 6       2000       월드클래스1
# 7       2100       월드클래스2
# 8       2200       월드클래스3
# 9       2300          프로1
# 10      2400          프로2
# 11      2500          프로3
# 12      2600        세미프로1
# 13      2700        세미프로2
# 14      2800        세미프로3
# 15      2900         유망주1
# 16      3000         유망주2
# 17      3100         유망주3

# %%
## 선수 고유 식별자
## 선수 고유 식별자의 메타데이터를 조회합니다. 선수 고유 식별자는 시즌아이디(seasonid) 3자리와 선수아이디(pid) 6자리로 구성되어 있습니다.

# %%
spId_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/spid.json')
spId_parsed_data = spId_url.json()
spId = pd.DataFrame(spId_parsed_data)

# %%
spId.head()
# Out:
#           id        name
# 0  100000250     데이비드 베컴
# 1  100001075     A. 델피에로
# 2  100001114     로베르토 바조
# 3  100001256  클라렌스 세이도르프
# 4  100001397      지네딘 지단

# %%
## 선수 포지션

# %%
spposition_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/spposition.json')
spposition_parsed_data = spposition_url.json()
spposition = pd.DataFrame(spposition_parsed_data)

# %%
spposition.head()
# Out:
#    spposition desc
# 0           0   GK
# 1           1   SW
# 2           2  RWB
# 3           3   RB
# 4           4  RCB

# %%
### 매치 기록 조회

# %%
# top20 매치데이터 불러오기
df = pd.read_csv("/Users/dongwook/Desktop/My_Project/Project_FIFA4/API_DATA/all_match.csv")

# %%
# matchInfo dic형식으로 변경
df['matchInfo'] = [eval(i) for i in df['matchInfo']]

# %%
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiNTAwOjEwIiwiYWNjb3VudF9pZCI6IjE2NjEyMDcwNTQiLCJhdXRoX2lkIjoiMiIsImV4cCI6MTcxMTYzNDcxNywiaWF0IjoxNjk2MDgyNzE3LCJuYmYiOjE2OTYwODI3MTcsInNlcnZpY2VfaWQiOiI0MzAwMTE0ODEiLCJ0b2tlbl90eXBlIjoiQWNjZXNzVG9rZW4ifQ.oFiZWJK1IreeBbJ4gaxGOWS71X6XKHcYdNvuUcqdmNM'

# %%
user_params = {'nickname' : 'KimYooMin'}
headers = {'Authorization' : api_key} # 조회시, headers 값 입력 필수 !
user_info_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users?', \
                             params = user_params, headers = headers)
user_parsed_data = user_info_url.json()
user_info_data = pd.DataFrame(user_parsed_data, index = [0])

# %%
# 유저 고유 식별자 확인
user_info_data
# Out:
#                    accessId   nickname  level
# 0  b0818f53b5f9bfb6be243066  KimYooMin   2244

# %%
# 내 아이디 조회
headers = {'Authorization' : api_key} # 조회시, headers 값 입력 필수 !
HOJJIMIN_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users/api_key', headers = headers) # 내 피파온라인 4 아이디

# %%
# 내 아이디 조회
headers = {'Authorization' : api_key}
user_params = {'nickname' : 'KimYooMin'}
# 피파온라인 4 아이디
ID_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users/api_key', \
                             params = user_params, headers = headers)

# %%
ID_parsed_data = ID_url.json()
print('My Information : ',ID_parsed_data)
ID = pd.DataFrame(ID_parsed_data, index = [0]) # Index 값 지정해줘야 데이터프레임 형태로 활용 가능
ID
# Out:
# My Information :  {'message': 'User could not found'}
#                 message
# 0  User could not found

# %%
HOJJIMIN_accessId = 'myaccessId' # API 조회 하기위한 나의 고유 Id 키 값
HOJJIMIN_accessId
# Out:
# 'myaccessId'

# %%
## 메타 데이터 정리

# %%
# 매치 종류 메타데이터 조회
match_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json')  
print(match_url) # <Response [200]> 호출 성공
match_parsed_data = match_url.json() # json 요청 및 파싱
match_type = pd.DataFrame(match_parsed_data)
match_type
# Out:
# <Response [200]>
#    matchtype      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선
# 5        204     볼타 친선
# 6        214     볼타 공식
# 7        224   볼타 AI대전
# 8        234    볼타 커스텀

# %%
# grade_data의 matchType 합치기 위한 전처리
match_type = match_type.rename(columns={'matchtype' : 'matchType'}) # 변수명 변경
match_type
# Out:
#    matchType      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선
# 5        204     볼타 친선
# 6        214     볼타 공식
# 7        224   볼타 AI대전
# 8        234    볼타 커스텀

# %%
# 피파온라인 등급 정보 데이터
division_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/division.json')
division_parsed_data = division_url.json()
print('division JSON : ', division_parsed_data)
division_data = pd.DataFrame(division_parsed_data)
division_data
# Out:
# division JSON :  [{'divisionId': 800, 'divisionName': '슈퍼챔피언스'}, {'divisionId': 900, 'divisionName': '챔피언스'}, {'divisionId': 1000, 'divisionName': '슈퍼챌린지'}, {'divisionId': 1100, 'divisionName': '챌린지1'}, {'divisionId': 1200, 'divisionName': '챌린지2'}, {'divisionId': 1300, 'divisionName': '챌린지3'}, {'divisionId': 2000, 'divisionName': '월드클래스1'}, {'divisionId': 2100, 'divisionName': '월드클래스2'}, {'divisionId': 2200, 'divisionName': '월드클래스3'}, {'divisionId': 2300, 'divisionName': '프로1'}, {'divisionId': 2400, 'divisionName': '프로2'}, {'divisionId': 2500, 'divisionName': '프로3'}, {'divisionId': 2600, 'divisionName': '세미프로1'}, {'divisionId': 2700, 'divisionName': '세미프로2'}, {'divisionId': 2800, 'divisionName': '세미프로3'}, {'divisionId': 2900, 'divisionName': '유망주1'}, {'divisionId': 3000, 'divisionName': '유망주2'}, {'divisionId': 3100, 'divisionName': '유망주3'}]
#     divisionId divisionName
# 0          800       슈퍼챔피언스
# 1          900         챔피언스
# 2         1000        슈퍼챌린지
# 3         1100         챌린지1
# 4         1200         챌린지2
# 5         1300         챌린지3
# 6         2000       월드클래스1
# 7         2100       월드클래스2
# 8         2200       월드클래스3
# 9         2300          프로1
# 10        2400          프로2
# 11        2500          프로3
# 12        2600        세미프로1
# 13        2700        세미프로2
# 14        2800        세미프로3
# 15        2900         유망주1
# 16        3000         유망주2
# 17        3100         유망주3

# %%
# division_data 데이터 전처리
division_data = division_data.rename(columns = {'divisionId' : 'division'})
division_data
# Out:
#     division divisionName
# 0        800       슈퍼챔피언스
# 1        900         챔피언스
# 2       1000        슈퍼챌린지
# 3       1100         챌린지1
# 4       1200         챌린지2
# 5       1300         챌린지3
# 6       2000       월드클래스1
# 7       2100       월드클래스2
# 8       2200       월드클래스3
# 9       2300          프로1
# 10      2400          프로2
# 11      2500          프로3
# 12      2600        세미프로1
# 13      2700        세미프로2
# 14      2800        세미프로3
# 15      2900         유망주1
# 16      3000         유망주2
# 17      3100         유망주3

# %%
# 매치 기록 조회

# %%
headers = {'Authorization' : api_key} 
match_params = {'matchtype' : 50, 'offset' : 0, 'limit' : 100}
match_record_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/users/b0818f53b5f9bfb6be243066/matches?',\
                                params=match_params, headers = headers)
match_record_parsed_data = match_record_url.json()
print(match_record_parsed_data) # 총 100건의 매치 조회
# Out:
# ['652026129996c6323faf56c5', '65202380b5de1420a88ddf9a', '65201f49dcf61659a9c2d15f', '65201c1446b9c115f39f7d49', '65201928b228563de9888099', '651d04451394bb15230e5942', '651d0091c415f95606cdb6b5', '651a5abcefe304ea38cacdfd', '65199b9899632f17d9b61f2e', '65195e7e88b9a71efd795ecc', '65195b05b8cf1e49a4eb8217', '651957e982a431f8b0fa9295', '65195445a2a1163e16061909', '651951af42faef7e8397487c', '65194edfb29a8656ac8f0189', '65194c0848928b19730af8ff', '6519494fa1ecf3252e9cab24', '65193bd936e72c70ac47d5b6', '651939705232141007f8e898', '651936b4fd52a03a9f6519e7', '65193537dab67baa18e65fa0', '65182412628bb9473799a643', '6518216ca120e11cf873fd40', '65181dfebcb43bfd906192b9', '65181b49c8a48ce853aaf34c', '65181802bc30c87564df178d', '651814ec6480c79ce961e570', '6518132fd8a936a6edec7e77', '6518105dae67715d2e346b22', '65180d6ac65a8cd75758b9bc', '65180acd55a8454b58d423f8', '651809538201360359efd50b', '651802c488b476a8c704fa43', '6518000028eda64098d0ac7b', '6517f0cd36b73541f1750edd', '6517ee2fcc1f6d1572bf4ead', '6517eb2679aa72524a23cae6', '6517e881970f69df86a7a734', '6517e5e4e6628dfc32673daa', '6517e1cf47842bc2a3976d5f', '6517def9e596dd5960d1ae8f', '6517dc169043c01f8c64f56f', '6517007f5bd11f40463f52d3', '6516d3d2fd1558637720c7aa', '6516d0b937e6c292b00f0521', '6515baedd73723e1be4ffa77', '6515b6c903416feb4eb01e6b', '6515b3d67936c10c90270ab2', '6515b154f6f885761154cf91', '6515ace38c069788b0403fdb', '6515aaf97cb75c2f75b5c7e7', '6515a8314d7eaec97f395225', '6515a74cfda5c1eedc01647e', '6515a3d8396a6519f80364f2', '6515a0d16da860b7240b31e3', '65159fd6400a8304831cc80a', '651567e1a8dd49195643afce', '65156421fa0b4a4beb065f4b', '65156083df58eb2d37c1da70', '65155d5a909c0f0a7969ef76', '65155a3419c3b93a2a887cdb', '651558654e92b684f431e9b7', '6515556212f5d1215d557772', '651551b37e053a22c12d0364', '65154ecf58ceadb4c1a7f8fb', '65154bf0282d9147e8feb338', '6515490836d9f4b4e46a72dd', '6515458e7b4f85d06d541c31', '651543ef27848f1e6dc818a1', '6515416c2dacc572f0b7807a', '6512e989ed5f2ca2421a1c93', '6512e59677493add4f28340e', '6512e34bf05bd86ff607368b', '6512dfb79b955727ce2aedac', '6512dd06dbd49b1c6da51a23', '6512d8bdbd54170282beb8ff', '6512d700f15df169569ff538', '6512d42a6b1498bfc3f3c783', '6512d0f6368dd53548468965', '6512ce28c9181f7be95be3dd', '6512c6d00dd303cf99bcbf2f', '6512c3ace7ccc67f8083cb16', '6512bddc14e6a9055b498471', '6512ba1938f9bf493e773bba', '65119a443197b29545213e01', '651195feb5eb4ccf29b3905e', '6511936b12421456dbd93502', '6511645573683339e6086bc7', '651161c127cb9a3df190da19', '65115e086610a4226de323fe', '651158c6bcfbad35a3244576', '651155957698ad67d2c8d8e6', '651152ecc723797f20a5824a', '651150c4dd3dfb04e5843bc5', '65114dd70a66b2130f8d920d', '65114c54a18cbeddbdd67a80', '651149a595fe3ad63d1b9381', '651144d684cab064ec3f763f', '6511423cc07904beb89e26a7', '65113f8c0716c585c4e3b20c']

# %%
type(match_record_parsed_data) # list 형태
# Out:
# list

# %%
# 매치 상세 기록 조회 데이터 부르기
match_HOJJIMIN = pd.DataFrame()
for idx, match in tqdm(enumerate(match_record_parsed_data)):
    matchid = match_record_parsed_data[idx]
    match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
    match_detail_parsed_data = match_detail_url.json()
    temp = pd.DataFrame(match_detail_parsed_data)
    match_HOJJIMIN = pd.concat([match_HOJJIMIN, temp], axis = 0)
    
match_HOJJIMIN # 매치 상세 기록 데이터
# Out:
# 0it [00:00, ?it/s]
#                      matchId            matchDate  matchType  \
# 0   652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 1   652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 0   65202380b5de1420a88ddf9a  2023-10-07T00:21:10         50
# 1   65202380b5de1420a88ddf9a  2023-10-07T00:21:10         50
# 0   65201f49dcf61659a9c2d15f  2023-10-07T00:08:25         50
# ..                       ...                  ...        ...
# 1   651144d684cab064ec3f763f  2023-09-25T17:39:51         50
# 0   6511423cc07904beb89e26a7  2023-09-25T17:28:30         50
# 1   6511423cc07904beb89e26a7  2023-09-25T17:28:30         50
# 0   65113f8c0716c585c4e3b20c  2023-09-25T17:17:24         50
# 1   65113f8c0716c585c4e3b20c  2023-09-25T17:17:24         50
#
#                                             matchInfo
# 0   {'accessId': '73567c13f185bf3121d50b52', 'nick...
# 1   {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 0   {'accessId': '7c5641c8e2b0a2688d83086a', 'nick...
# 1   {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 0   {'accessId': '1d11718983ac42e41e1b4ebf', 'nick...
# ..                                                ...
# 1   {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 0   {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 1   {'accessId': '4500a4eaa5d8fea26734c4dc', 'nick...
# 0   {'accessId': '198700bd7f5c53b16dd0a669', 'nick...
# 1   {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
#
# [200 rows x 4 columns]

# %%
# 인덱스 변경
plus_index = list()
for i in range(0, 100):
    temp1 = i
    temp2 = i
    plus_index.append(temp1)
    plus_index.append(temp2)

len(plus_index)
# Out:
# 200

# %%
match_HOJJIMIN['change_index'] = plus_index
match_HOJJIMIN.head(3)
# Out:
#                     matchId            matchDate  matchType  \
# 0  652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 1  652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 0  65202380b5de1420a88ddf9a  2023-10-07T00:21:10         50
#
#                                            matchInfo  change_index
# 0  {'accessId': '73567c13f185bf3121d50b52', 'nick...             0
# 1  {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...             0
# 0  {'accessId': '7c5641c8e2b0a2688d83086a', 'nick...             1

# %%
match_HOJJIMIN = match_HOJJIMIN.set_index('change_index', drop=True) # 인덱스 변경
match_HOJJIMIN
# Out:
#                                matchId            matchDate  matchType  \
# change_index
# 0             652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 0             652026129996c6323faf56c5  2023-10-07T00:32:12         50
# 1             65202380b5de1420a88ddf9a  2023-10-07T00:21:10         50
# 1             65202380b5de1420a88ddf9a  2023-10-07T00:21:10         50
# 2             65201f49dcf61659a9c2d15f  2023-10-07T00:08:25         50
# ...                                ...                  ...        ...
# 97            651144d684cab064ec3f763f  2023-09-25T17:39:51         50
# 98            6511423cc07904beb89e26a7  2023-09-25T17:28:30         50
# 98            6511423cc07904beb89e26a7  2023-09-25T17:28:30         50
# 99            65113f8c0716c585c4e3b20c  2023-09-25T17:17:24         50
# 99            65113f8c0716c585c4e3b20c  2023-09-25T17:17:24         50
#
#                                                       matchInfo
# change_index
# 0             {'accessId': '73567c13f185bf3121d50b52', 'nick...
# 0             {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 1             {'accessId': '7c5641c8e2b0a2688d83086a', 'nick...
# 1             {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 2             {'accessId': '1d11718983ac42e41e1b4ebf', 'nick...
# ...                                                         ...
# 97            {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 98            {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
# 98            {'accessId': '4500a4eaa5d8fea26734c4dc', 'nick...
# 99            {'accessId': '198700bd7f5c53b16dd0a669', 'nick...
# 99            {'accessId': 'b0818f53b5f9bfb6be243066', 'nick...
#
# [200 rows x 4 columns]

# %%
# 첫 번째 데이터를 통해 어떤 형식으로 이루어져 있는가 확인해보자
matchid = match_record_parsed_data[0]
match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
match_detail_parsed_data = match_detail_url.json()
match_detail_parsed_data # 해당 데이터의 형태
# Out:
# {'matchId': '652026129996c6323faf56c5',
#  'matchDate': '2023-10-07T00:32:12',
#  'matchType': 50,
#  'matchInfo': [{'accessId': '73567c13f185bf3121d50b52',
#    'nickname': 'Prime천문기',
#    'matchDetail': {'seasonId': 202310,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 88,
#     'cornerKick': 3,
#     'possession': 53,
#     'offsideCount': 2,
#     'averageRating': 3.71667,
#     'controller': 'gamepad'},
#    'shoot': {'shootTotal': 6,
#     'effectiveShootTotal': 3,
#     'shootOutScore': 0,
#     'goalTotal': 1,
#     'goalTotalDisplay': 1,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 5,
#     'goalInPenalty': 1,
#     'shootOutPenalty': 1,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 548,
#      'x': 0.8540518879890442,
#      'y': 0.4162636995315552,
#      'type': 1,
#      'result': 2,
#      'spId': 289020801,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 246001620,
#      'assistX': 0.6599836945533752,
#      'assistY': 0.4670723676681519,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1408,
#      'x': 0.8793375492095947,
#      'y': 0.5697187185287476,
#      'type': 6,
#      'result': 2,
#      'spId': 100003647,
#      'spGrade': 2,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 289020801,
#      'assistX': 0.9257147908210754,
#      'assistY': 0.674087643623352,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1733,
#      'x': 0.9199592471122742,
#      'y': 0.559788167476654,
#      'type': 6,
#      'result': 2,
#      'spId': 268005589,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 289020801,
#      'assistX': 0.9026879072189332,
#      'assistY': 0.64509642124176,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2477,
#      'x': 0.8437907695770264,
#      'y': 0.43410250544548,
#      'type': 2,
#      'result': 1,
#      'spId': 101214100,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 289020801,
#      'assistX': 0.8329563140869141,
#      'assistY': 0.5158688426017761,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2724,
#      'x': 0.7938469052314758,
#      'y': 0.5794023275375366,
#      'type': 1,
#      'result': 1,
#      'spId': 101214100,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 268005589,
#      'assistX': 0.7168195843696594,
#      'assistY': 0.7017778754234314,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16780059,
#      'x': 0.9615347981452942,
#      'y': 0.6282643675804138,
#      'type': 1,
#      'result': 3,
#      'spId': 289020801,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 101214100,
#      'assistX': 0.6421937942504883,
#      'assistY': 0.8426716327667236,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 136,
#     'passSuccess': 129,
#     'shortPassTry': 115,
#     'shortPassSuccess': 108,
#     'longPassTry': 4,
#     'longPassSuccess': 3,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 17,
#     'throughPassSuccess': 17,
#     'lobbedThroughPassTry': 1,
#     'lobbedThroughPassSuccess': 1},
#    'defence': {'blockTry': 9,
#     'blockSuccess': 2,
#     'tackleTry': 17,
#     'tackleSuccess': 9},
#    'player': [{'spId': 318172723,
#      'spPosition': 28,
#      'spGrade': 9,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 234192119,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 3,
#       'passTry': 2,
#       'passSuccess': 2,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 242205452,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 82,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 3,
#       'block': 1,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.2}},
#     {'spId': 217227796,
#      'spPosition': 28,
#      'spGrade': 9,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 260235212,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 67,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 4.3}},
#     {'spId': 317239138,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 510252278,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289020801,
#      'spPosition': 26,
#      'spGrade': 5,
#      'status': {'shoot': 2,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 251,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 20,
#       'passSuccess': 19,
#       'dribbleTry': 13,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 101214100,
#      'spPosition': 24,
#      'spGrade': 5,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 217,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 27,
#       'passSuccess': 26,
#       'dribbleTry': 15,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 234001040,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 141,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 8,
#       'dribbleTry': 6,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.5}},
#     {'spId': 246001620,
#      'spPosition': 11,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 216,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 20,
#       'passSuccess': 19,
#       'dribbleTry': 11,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 100003647,
#      'spPosition': 9,
#      'spGrade': 2,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 139,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 24,
#       'passSuccess': 23,
#       'dribbleTry': 14,
#       'dribbleSuccess': 14,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.4}},
#     {'spId': 268005589,
#      'spPosition': 12,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 335,
#       'intercept': 3,
#       'defending': 0,
#       'passTry': 16,
#       'passSuccess': 15,
#       'dribbleTry': 13,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 9,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 3,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}},
#     {'spId': 225103133,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256192985,
#      'spPosition': 16,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 139,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 5,
#       'dribbleTry': 7,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.2}},
#     {'spId': 510230921,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 300243780,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 280240130,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 36,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 5,
#       'passSuccess': 5,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 1,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 4.9}}]},
#   {'accessId': 'b0818f53b5f9bfb6be243066',
#    'nickname': 'KimYooMin',
#    'matchDetail': {'seasonId': 202310,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 72,
#     'cornerKick': 3,
#     'possession': 47,
#     'offsideCount': 1,
#     'averageRating': 4.62222,
#     'controller': 'gamepad'},
#    'shoot': {'shootTotal': 6,
#     'effectiveShootTotal': 6,
#     'shootOutScore': 0,
#     'goalTotal': 4,
#     'goalTotalDisplay': 4,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 6,
#     'goalInPenalty': 4,
#     'shootOutPenalty': 0,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 1522,
#      'x': 0.8872844576835632,
#      'y': 0.3811357021331787,
#      'type': 1,
#      'result': 3,
#      'spId': 268045661,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 268254642,
#      'assistX': 0.3844967186450958,
#      'assistY': 0.06576207280158997,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777390,
#      'x': 0.8566581010818481,
#      'y': 0.46775859594345,
#      'type': 1,
#      'result': 1,
#      'spId': 268045661,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 221197445,
#      'assistX': 0.8183789253234863,
#      'assistY': 0.2043667435646057,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778694,
#      'x': 0.9429208636283876,
#      'y': 0.5862073302268982,
#      'type': 6,
#      'result': 3,
#      'spId': 110009676,
#      'spGrade': 1,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 234183277,
#      'assistX': 0.9167115092277528,
#      'assistY': 0.8768453598022461,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779300,
#      'x': 0.9270745515823364,
#      'y': 0.5773454904556274,
#      'type': 3,
#      'result': 1,
#      'spId': 110009676,
#      'spGrade': 1,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 320,
#      'x': 0.9635505080223083,
#      'y': 0.6358396410942078,
#      'type': 1,
#      'result': 3,
#      'spId': 234183277,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 110009676,
#      'assistX': 0.7830385565757751,
#      'assistY': 0.7162390947341919,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1115,
#      'x': 0.8893759250640869,
#      'y': 0.55096834897995,
#      'type': 6,
#      'result': 3,
#      'spId': 256177003,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 268045661,
#      'assistX': 0.9179982542991638,
#      'assistY': 0.6863071918487549,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 82,
#     'passSuccess': 76,
#     'shortPassTry': 59,
#     'shortPassSuccess': 58,
#     'longPassTry': 2,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 1,
#     'bouncingLobPassSuccess': 1,
#     'drivenGroundPassTry': 3,
#     'drivenGroundPassSuccess': 2,
#     'throughPassTry': 14,
#     'throughPassSuccess': 12,
#     'lobbedThroughPassTry': 2,
#     'lobbedThroughPassSuccess': 1},
#    'defence': {'blockTry': 14,
#     'blockSuccess': 2,
#     'tackleTry': 17,
#     'tackleSuccess': 8},
#    'player': [{'spId': 298244798,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 268254642,
#      'spPosition': 16,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 180,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.6}},
#     {'spId': 300003467,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 110009676,
#      'spPosition': 24,
#      'spGrade': 1,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 1,
#       'goal': 1,
#       'dribble': 87,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 11,
#       'dribbleTry': 9,
#       'dribbleSuccess': 7,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 1,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.4}},
#     {'spId': 268045661,
#      'spPosition': 26,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 1,
#       'goal': 1,
#       'dribble': 372,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 8,
#       'dribbleTry': 10,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.6}},
#     {'spId': 256177003,
#      'spPosition': 11,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 306,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 9,
#       'dribbleTry': 12,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.8}},
#     {'spId': 251182521,
#      'spPosition': 9,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 154,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 9,
#       'dribbleTry': 11,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 5,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.9}},
#     {'spId': 234183277,
#      'spPosition': 12,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 1,
#       'dribble': 521,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 6,
#       'dribbleTry': 8,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.5}},
#     {'spId': 501183512,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 300192119,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 6,
#       'passTry': 5,
#       'passSuccess': 5,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 221197445,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 177,
#       'intercept': 3,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 8,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 4,
#       'tackle': 3,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.1}},
#     {'spId': 242205452,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 9,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 3,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 4,
#       'block': 1,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.0}},
#     {'spId': 260208618,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 71,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 1,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 320216335,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 257225733,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 512238763,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 287240130,
#      'spPosition': 6,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 41,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 3,
#       'block': 0,
#       'tackleTry': 4,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}},
#     {'spId': 295243242,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]}]}

# %%
# DTO 정보 리스트 형태로 만들기

accessId_list = [m.get('accessId') for m in df['matchInfo']]
nickname_list = [m.get('nickname') for m in df['matchInfo']]
matchDetail_list = [m.get('matchDetail') for m in df['matchInfo']]
shootDetail_list = [m.get('shoot') for m in df['matchInfo']]
passDetail_list = [m.get('pass') for m in df['matchInfo']]
defenceDetail_list = [m.get('defence') for m in df['matchInfo']]

print('accessInfo 리스트 갯수 : ', len(accessId_list))
print('nicknameInfo 리스트 갯수 : ', len(nickname_list))
print('matchInfo 리스트 갯수 : ', len(matchDetail_list))
print('shoot 리스트 갯수 : ', len(shootDetail_list))
print('pass 리스트 갯수 : ', len(passDetail_list))
print('defence 리스트 갯수 : ', len( defenceDetail_list))
# Out:
# accessInfo 리스트 갯수 :  3797
# nicknameInfo 리스트 갯수 :  3797
# matchInfo 리스트 갯수 :  3797
# shoot 리스트 갯수 :  3797
# pass 리스트 갯수 :  3797
# defence 리스트 갯수 :  3797

# %%
match_info_data = df.iloc[:, [0,1,2]].reset_index(drop = True)
accessId_data = pd.DataFrame(accessId_list)
nickname_data = pd.DataFrame(nickname_list)
match_detail_data = pd.DataFrame(matchDetail_list)
match_shoot_data = pd.DataFrame(shootDetail_list)
match_pass_data = pd.DataFrame(passDetail_list)
match_defence_data = pd.DataFrame(defenceDetail_list)

print('Shape of match_info_data : ', match_info_data.shape)
print('Shape of accessId_data : ', accessId_data.shape)
print('Shape of nickname_data : ', nickname_data.shape)
print('Shape of match_detail_data : ', match_detail_data.shape)
print('Shape of match_shoot_data : ', match_shoot_data.shape)
print('Shape of match_pass_data : ', match_pass_data.shape)
print('Shape of match_defence_data : ', match_defence_data.shape)
# Out:
# Shape of match_info_data :  (3797, 3)
# Shape of accessId_data :  (3797, 1)
# Shape of nickname_data :  (3797, 1)
# Shape of match_detail_data :  (3797, 14)
# Shape of match_shoot_data :  (3797, 16)
# Shape of match_pass_data :  (3797, 14)
# Shape of match_defence_data :  (3797, 4)

# %%
accessId_data = accessId_data.rename(columns={0 : 'accessId'}) # 컬럼명 변경
accessId_data.head(3)
# Out:
#                    accessId
# 0  472eeb0a2c2069238365d8de
# 1  b0818f53b5f9bfb6be243066
# 2  7fae4fecf2675c1817831c4f

# %%
nickname_data.head(5)
# Out:
#            0
# 0  Eunice오추마
# 1  KimYooMin
# 2      금전수S2
# 3  KimYooMin
# 4     KDF정성민

# %%
nickname_data = nickname_data.rename(columns={0 : 'nickname'}) # 컬럼명 변경
nickname_data.head(3)
# Out:
#     nickname
# 0  Eunice오추마
# 1  KimYooMin
# 2      금전수S2

# %%
match_detail_data.head(3)
# Out:
#    seasonId matchResult  matchEndType  systemPause  foul  injury  redCards  \
# 0    202310           패             0            0     0       0         0
# 1    202310           승             0            0     0       0         0
# 2    202310           패             0            0     1       0         0
#
#    yellowCards  dribble  cornerKick  possession  offsideCount  averageRating  \
# 0            0       72           1          42             0        3.85000
# 1            0       84           1          58             0        4.44444
# 2            0       73           3          48             0        3.90000
#
#   controller
# 0    gamepad
# 1    gamepad
# 2    gamepad

# %%
match_shoot_data.head(3)
# Out:
#    shootTotal  effectiveShootTotal  shootOutScore  goalTotal  \
# 0           6                    4              0          1
# 1           4                    4              0          3
# 2           8                    5              0          2
#
#    goalTotalDisplay  ownGoal  shootHeading  goalHeading  shootFreekick  \
# 0                 1        0             1            0              0
# 1                 3        0             0            0              0
# 2                 2        0             1            0              0
#
#    goalFreekick  shootInPenalty  goalInPenalty  shootOutPenalty  \
# 0             0               5              1                1
# 1             0               3              2                1
# 2             0               4              2                4
#
#    goalOutPenalty  shootPenaltyKick  goalPenaltyKick
# 0               0                 0                0
# 1               1                 0                0
# 2               0                 0                0

# %%
match_pass_data.head(3)
# Out:
#    passTry  passSuccess  shortPassTry  shortPassSuccess  longPassTry  \
# 0      105           93            80                76            4
# 1      123          112            95                90            5
# 2      106           99            78                77            5
#
#    longPassSuccess  bouncingLobPassTry  bouncingLobPassSuccess  \
# 0                3                   0                       0
# 1                2                   0                       0
# 2                3                   0                       0
#
#    drivenGroundPassTry  drivenGroundPassSuccess  throughPassTry  \
# 0                    2                        2              10
# 1                    8                        7              13
# 2                    1                        1              21
#
#    throughPassSuccess  lobbedThroughPassTry  lobbedThroughPassSuccess
# 0                   8                     6                         4
# 1                  12                     1                         1
# 2                  18                     0                         0

# %%
match_defence_data.head(3)
# Out:
#    blockTry  blockSuccess  tackleTry  tackleSuccess
# 0        10             1         17              5
# 1        10             0          7              4
# 2        10             1         11              7

# %%
top20_match = pd.concat([match_info_data, accessId_data, nickname_data, match_detail_data, match_shoot_data, match_pass_data, match_defence_data], axis = 1)
top20_match.shape
# Out:
# (3797, 53)

# %%
top20_match
# Out:
#       Unnamed: 0  index                   matchId                  accessId  \
# 0              0      0  65182412628bb9473799a643  472eeb0a2c2069238365d8de
# 1              1      1  65182412628bb9473799a643  b0818f53b5f9bfb6be243066
# 2              2      0  6518216ca120e11cf873fd40  7fae4fecf2675c1817831c4f
# 3              3      1  6518216ca120e11cf873fd40  b0818f53b5f9bfb6be243066
# 4              4      0  65181dfebcb43bfd906192b9  1a8cb72f15412d60711ac2e8
# ...          ...    ...                       ...                       ...
# 3792         194      1  64f9d71a70a64b62fc3833bb  5e65bc04909b2c940843bee7
# 3793         195      0  64f9d472edfcdf166b18e81f  5e65bc04909b2c940843bee7
# 3794         196      1  64f9d472edfcdf166b18e81f  ce7f2b03d1c7d484648afad4
# 3795         197      0  64f9d1e55aabc8a8c115ad61  4c15fa2918f224de85de934d
# 3796         198      1  64f9d1e55aabc8a8c115ad61  5e65bc04909b2c940843bee7
#
#        nickname  seasonId matchResult  matchEndType  systemPause  foul  ...  \
# 0     Eunice오추마    202310           패             0            0     0  ...
# 1     KimYooMin    202310           승             0            0     0  ...
# 2         금전수S2    202310           패             0            0     1  ...
# 3     KimYooMin    202310           승             0            0     0  ...
# 4        KDF정성민    202310           무             0            0     3  ...
# ...         ...       ...         ...           ...          ...   ...  ...
# 3792         청소    202309           패             0            0     2  ...
# 3793         청소    202309           승             0            0     1  ...
# 3794    I0MESSI    202309           패             0            0     0  ...
# 3795      골퍼하프로    202309           패             0            0     3  ...
# 3796         청소    202309           승             0            0     1  ...
#
#       drivenGroundPassTry  drivenGroundPassSuccess  throughPassTry  \
# 0                       2                        2              10
# 1                       8                        7              13
# 2                       1                        1              21
# 3                       4                        4              13
# 4                       1                        0              19
# ...                   ...                      ...             ...
# 3792                    1                        1              13
# 3793                    2                        2              12
# 3794                    0                        0               5
# 3795                    9                        8              22
# 3796                    1                        1              17
#
#       throughPassSuccess  lobbedThroughPassTry  lobbedThroughPassSuccess  \
# 0                      8                     6                         4
# 1                     12                     1                         1
# 2                     18                     0                         0
# 3                     13                     0                         0
# 4                     18                     0                         0
# ...                  ...                   ...                       ...
# 3792                  11                     0                         0
# 3793                  12                     0                         0
# 3794                   5                     3                         1
# 3795                  19                     1                         0
# 3796                  16                     0                         0
#
#       blockTry  blockSuccess tackleTry  tackleSuccess
# 0           10             1        17              5
# 1           10             0         7              4
# 2           10             1        11              7
# 3            8             1        13              3
# 4           12             1        13              6
# ...        ...           ...       ...            ...
# 3792         8             0        22             12
# 3793         9             1         9              3
# 3794        11             1         3              0
# 3795         9             2        16             10
# 3796         5             1        17              9
#
# [3797 rows x 53 columns]

# %%
shootDetail_list = [m.get('shootDetail') for m in df['matchInfo']]
player_list = [m.get('player') for m in df['matchInfo']]

# %%
print('shootDetail 리스트 갯수 : ', len(shootDetail_list))
print('player 리스트 갯수 : ', len(player_list))
# Out:
# shootDetail 리스트 갯수 :  3797
# player 리스트 갯수 :  3797

# %%
shootDetail_list[0]
# Out:
# [{'goalTime': 586,
#   'x': 0.9056668281555176,
#   'y': 0.5744364261627197,
#   'type': 3,
#   'result': 2,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': False,
#   'assistSpId': -1,
#   'assistX': 0.5,
#   'assistY': 0.5,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 928,
#   'x': 0.9478583335876464,
#   'y': 0.4414625763893127,
#   'type': 6,
#   'result': 3,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 268000027,
#   'assistX': 0.8243390321731567,
#   'assistY': 0.8620988130569458,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 1708,
#   'x': 0.9337079524993896,
#   'y': 0.5812775492668152,
#   'type': 1,
#   'result': 2,
#   'spId': 101214100,
#   'spGrade': 5,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': False,
#   'assistSpId': -1,
#   'assistX': 0.5,
#   'assistY': 0.5,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 2693,
#   'x': 0.79596734046936,
#   'y': 0.5947598218917847,
#   'type': 1,
#   'result': 1,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 101214100,
#   'assistX': 0.651938796043396,
#   'assistY': 0.6029800176620483,
#   'hitPost': False,
#   'inPenalty': False},
#  {'goalTime': 2842,
#   'x': 0.8786041140556335,
#   'y': 0.6618544459342957,
#   'type': 2,
#   'result': 1,
#   'spId': 100003647,
#   'spGrade': 3,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 268001116,
#   'assistX': 0.7605552077293396,
#   'assistY': 0.5039323568344116,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 16778987,
#   'x': 0.8758916258811951,
#   'y': 0.287661612033844,
#   'type': 2,
#   'result': 1,
#   'spId': 254001201,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 100003647,
#   'assistX': 0.5696955919265747,
#   'assistY': 0.3254602253437042,
#   'hitPost': False,
#   'inPenalty': True}]

# %%
# 이미지 활용

# %%
pip install opencv-contrib-python
# Out:
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# Requirement already satisfied: opencv-contrib-python in /Users/dongwook/opt/anaconda3/lib/python3.8/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.3 in /Users/dongwook/opt/anaconda3/lib/python3.8/site-packages (from opencv-contrib-python) (1.19.5)
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/dongwook/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/dongwook/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
## 득점 정보
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/Users/dongwook/Desktop/My_Project/Project_FIFA4/CODE_TEST/경기장.jpeg')
cv2.imshow('img', image)

# %%
imageLine = image.copy()

# %%
# cv2.line(img, start, end, color[, thickness, lineType]) - 직선그리기

# %%
shootDetail_list[0]
# Out:
# [{'goalTime': 586,
#   'x': 0.9056668281555176,
#   'y': 0.5744364261627197,
#   'type': 3,
#   'result': 2,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': False,
#   'assistSpId': -1,
#   'assistX': 0.5,
#   'assistY': 0.5,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 928,
#   'x': 0.9478583335876464,
#   'y': 0.4414625763893127,
#   'type': 6,
#   'result': 3,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 268000027,
#   'assistX': 0.8243390321731567,
#   'assistY': 0.8620988130569458,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 1708,
#   'x': 0.9337079524993896,
#   'y': 0.5812775492668152,
#   'type': 1,
#   'result': 2,
#   'spId': 101214100,
#   'spGrade': 5,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': False,
#   'assistSpId': -1,
#   'assistX': 0.5,
#   'assistY': 0.5,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 2693,
#   'x': 0.79596734046936,
#   'y': 0.5947598218917847,
#   'type': 1,
#   'result': 1,
#   'spId': 268013128,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 101214100,
#   'assistX': 0.651938796043396,
#   'assistY': 0.6029800176620483,
#   'hitPost': False,
#   'inPenalty': False},
#  {'goalTime': 2842,
#   'x': 0.8786041140556335,
#   'y': 0.6618544459342957,
#   'type': 2,
#   'result': 1,
#   'spId': 100003647,
#   'spGrade': 3,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 268001116,
#   'assistX': 0.7605552077293396,
#   'assistY': 0.5039323568344116,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 16778987,
#   'x': 0.8758916258811951,
#   'y': 0.287661612033844,
#   'type': 2,
#   'result': 1,
#   'spId': 254001201,
#   'spGrade': 8,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 100003647,
#   'assistX': 0.5696955919265747,
#   'assistY': 0.3254602253437042,
#   'hitPost': False,
#   'inPenalty': True}]

# %%
1080*0.9
# Out:
# 972.0

# %%
# 선그리기
cv2.line(imageLine, (int(1080*0.9),int(1920*0.57)), (int(1080*0.5),int(1920*0.5)), (0,255,0), thickness=2, lineType=cv2.LINE_AA)
# cv2.imshow('image line', imageLine)
# cv2.waitKey(10)
# cv2.destroyAllWindows()
# Out:
# -1

# %%
plt.imshow(image)

# %%
x1 = int(1920*(1-0.57))
y1 = int(1080*(1-0.9))
x2 = int(1920*(1-0.5))
y2 = int(1080*(1-0.5))
test2 = cv2.line(imageLine, (x1,y1), (x2,y2), (0,255,0), thickness=2, lineType=cv2.LINE_AA)

# %%
x = 0.9056668281555176
y = 0.5744364261627197
assistX = 0.5
assistY = 0.5

# %%
# 최종 : 넥슨 api의 x,y 좌표와 cv2 좌표가 다름
x1 = int(1080*(1-y))
y1 = int(1920*(x))
x2 = int(1080*(assistY))
y2 = int(1920*(assistX))
test2 = cv2.line(imageLine, (y1,x1), (y2,x2), (0,255,0), thickness=2, lineType=cv2.LINE_AA)

# %%
imageLine = image.copy()

# %%
plt.imshow(test2)

# %%
print('image.shape ', image.shape)
# Out:
# image.shape  (1080, 1920, 3)

# %%
# png 형식으로 저장
# cv2.imwrite('저장할이미지이름.png', 이미지 파일)
